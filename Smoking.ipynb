# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from functions.LoadingData import LoadData
# %matplotlib inline

# %%
d = LoadData('data/smoking.csv')
smoking = d.create_data()
# Out:
# Shape of DataFrame is (55692, 27)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55692 entries, 0 to 55691
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   55692 non-null  int64
#  1   gender               55692 non-null  object
#  2   age                  55692 non-null  int64
#  3   height(cm)           55692 non-null  int64
#  4   weight(kg)           55692 non-null  int64
#  5   waist(cm)            55692 non-null  float64
#  6   eyesight(left)       55692 non-null  float64
#  7   eyesight(right)      55692 non-null  float64
#  8   hearing(left)        55692 non-null  float64
#  9   hearing(right)       55692 non-null  float64
#  10  systolic             55692 non-null  float64
#  11  relaxation           55692 non-null  float64
#  12  fasting blood sugar  55692 non-null  float64
#  13  Cholesterol          55692 non-null  float64
# ...

# %%
smoking.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              1.0            1.0             1.0  ...        12.9
# 1              0.6            1.0             1.0  ...        12.7
# 2              0.8            1.0             1.0  ...        15.8
# 3              1.5            1.0             1.0  ...        14.7
# 4              1.0            1.0             1.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...

# %%
smoking.drop('ID', axis=1, inplace=True)
smoking.head()
# Out:
#   gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0      F   40         155          60       81.3             1.2
# 1      F   40         160          60       81.0             0.8
# 2      M   55         170          60       80.0             0.8
# 3      M   40         165          70       88.0             1.5
# 4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  hemoglobin  \
# 0              1.0            1.0             1.0     114.0  ...        12.9
# 1              0.6            1.0             1.0     119.0  ...        12.7
# 2              0.8            1.0             1.0     138.0  ...        15.8
# 3              1.5            1.0             1.0     100.0  ...        14.7
# 4              1.0            1.0             1.0     120.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...

# %%
sns.jointplot(data=smoking,
                x='weight(kg)',
                y='height(cm)')

# %%
sns.countplot(data=smoking, x='age', hue='smoking')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=smoking, x='hemoglobin', y='age', hue='smoking')
# Out:
# <AxesSubplot:xlabel='hemoglobin', ylabel='age'>

# %%
sns.countplot(data=smoking, x='gender', hue='smoking')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# As we can see most of the smokers are men, gender feature is going to have high parameter weight in our machine learning model

# %%
sns.scatterplot(data=smoking, x='age', y='AST', hue='smoking')
# Out:
# <AxesSubplot:xlabel='age', ylabel='AST'>

# %%
sns.scatterplot(data=smoking, x='age', y='ALT', hue='smoking')
# Out:
# <AxesSubplot:xlabel='age', ylabel='ALT'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=smoking, y='age', x='Gtp', hue='smoking')
# Out:
# <AxesSubplot:xlabel='Gtp', ylabel='age'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=smoking, y='age', x='serum creatinine', hue='smoking')
# Out:
# <AxesSubplot:xlabel='serum creatinine', ylabel='age'>

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
smoking.head()
# Out:
#   gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0      F   40         155          60       81.3             1.2
# 1      F   40         160          60       81.0             0.8
# 2      M   55         170          60       80.0             0.8
# 3      M   40         165          70       88.0             1.5
# 4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  hemoglobin  \
# 0              1.0            1.0             1.0     114.0  ...        12.9
# 1              0.6            1.0             1.0     119.0  ...        12.7
# 2              0.8            1.0             1.0     138.0  ...        15.8
# 3              1.5            1.0             1.0     100.0  ...        14.7
# 4              1.0            1.0             1.0     120.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...

# %%
smoking_dummies = pd.get_dummies(data=smoking,columns=['gender', 'oral', 'tartar'], drop_first=True)

# %%
smoking_dummies.head()
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   40         155          60       81.3             1.2              1.0
# 1   40         160          60       81.0             0.8              0.6
# 2   55         170          60       80.0             0.8              0.8
# 3   40         165          70       88.0             1.5              1.5
# 4   40         155          60       86.0             1.0              1.0
#
#    hearing(left)  hearing(right)  systolic  relaxation  ...  hemoglobin  \
# 0            1.0             1.0     114.0        73.0  ...        12.9
# 1            1.0             1.0     119.0        70.0  ...        12.7
# 2            1.0             1.0     138.0        86.0  ...        15.8
# 3            1.0             1.0     100.0        60.0  ...        14.7
# 4            1.0             1.0     120.0        74.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  dental caries  smoking  \
# ...

# %%
smoking_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55692 entries, 0 to 55691
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  55692 non-null  int64
#  1   height(cm)           55692 non-null  int64
#  2   weight(kg)           55692 non-null  int64
#  3   waist(cm)            55692 non-null  float64
#  4   eyesight(left)       55692 non-null  float64
#  5   eyesight(right)      55692 non-null  float64
#  6   hearing(left)        55692 non-null  float64
#  7   hearing(right)       55692 non-null  float64
#  8   systolic             55692 non-null  float64
#  9   relaxation           55692 non-null  float64
#  10  fasting blood sugar  55692 non-null  float64
#  11  Cholesterol          55692 non-null  float64
#  12  triglyceride         55692 non-null  float64
#  13  HDL                  55692 non-null  float64
#  14  LDL                  55692 non-null  float64
# ...

# %%
scaler = StandardScaler()
smoking_scaled = scaler.fit_transform(smoking_dummies.drop('smoking',axis=1))
smoking_scaled
# Out:
# array([[-0.34651724, -1.04946503, -0.45747648, ..., -0.52075676,
#         -1.32085772,  0.89442719],
#        [-0.34651724, -0.50566252, -0.45747648, ..., -0.52075676,
#         -1.32085772,  0.89442719],
#        [ 0.8960986 ,  0.58194251, -0.45747648, ..., -0.52075676,
#          0.75708381, -1.11803399],
#        ...,
#        [ 0.8960986 , -0.50566252, -1.23749609, ..., -0.52075676,
#         -1.32085772, -1.11803399],
#        [ 1.31030388,  0.03814   , -0.45747648, ..., -0.52075676,
#          0.75708381, -1.11803399],
#        [ 0.8960986 , -0.50566252, -0.06746668, ..., -0.52075676,
#          0.75708381,  0.89442719]])

# %%
component_analisys = PCA()
component_analisys.fit_transform(smoking_scaled)
variance = component_analisys.explained_variance_ratio_
plt.figure(figsize=(10,7))
sns.barplot(x=np.arange(len(variance)), y=variance)
plt.xlabel('Feature Number in data set')
plt.ylabel('Importance of feature')
# Out:
# Text(0, 0.5, 'Importance of feature')

# %%
X= smoking_scaled
X.shape
# Out:
# (55692, 24)

# %%
y = smoking['smoking'].values

# %%
from sklearn.model_selection import train_test_split
from xgboost.sklearn import XGBClassifier
from functions.scores import ModelMetrics
from sklearn.ensemble import GradientBoostingClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
import optuna
from sklearn.metrics import log_loss

# %%
def tuning_xgb():
    def objective(trial):
        params = {
        "n_estimators": trial.suggest_int('n_estimators',1,100),
        "reg_alpha":trial.suggest_float('reg_alpha',0.1,0.9),
        "max_depth" : trial.suggest_int("max_depth",1,20),
        "max_leaves": trial.suggest_int('max_leaves',0,200),
        "eta" : trial.suggest_float("eta",0.001, 1.0),
        "min_child_weight" : trial.suggest_int("min_child_weight",1,20),
        "subsample" : trial.suggest_float("subsample",0.1,0.9),
        "gamma" : trial.suggest_float("gamma",0.01,0.9),
        "gpu_id": 0,
        "tree_method" : "gpu_hist",
        "objective" : "binary:logistic",
        }
        xgb = XGBClassifier(**params)
        xgb.fit(X_train,y_train)
        y_pred = xgb.predict_proba(X_test)
        error = log_loss(y_test, y_pred)
        return np.sqrt(error)
    return objective

func1 = tuning_xgb()

study_xgb = optuna.create_study(direction="minimize",study_name="XgBoostClassifier")
study_xgb.optimize(func1,n_trials=10)
print(study_xgb.best_params)
# Out:
# [I 2022-05-08 21:01:01,560] A new study created in memory with name: XgBoostClassifier
# [I 2022-05-08 21:01:02,856] Trial 0 finished with value: 0.6790512150715247 and parameters: {'n_estimators': 19, 'reg_alpha': 0.6066297013795576, 'max_depth': 5, 'max_leaves': 189, 'eta': 0.22198865411768376, 'min_child_weight': 7, 'subsample': 0.8899733261235178, 'gamma': 0.5320600872588898}. Best is trial 0 with value: 0.6790512150715247.
# [I 2022-05-08 21:01:02,953] Trial 1 finished with value: 0.7198720449512501 and parameters: {'n_estimators': 3, 'reg_alpha': 0.616326766482461, 'max_depth': 10, 'max_leaves': 3, 'eta': 0.47714016893351036, 'min_child_weight': 12, 'subsample': 0.507479438534728, 'gamma': 0.14228379681885414}. Best is trial 0 with value: 0.6790512150715247.
# ...

# %%
xgb_model = XGBClassifier(**study_xgb.best_params)
eval = ModelMetrics(xgb_model, 'classification', X_train, y_train, X_test, y_test)
eval.model_performance()
# Out:
# Cross validation mean score is 0.23450780271985638
# Log Loss for test set is 0.4562
# Confusion matrix for test set
# [[2829  676]
#  [ 654 1411]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81      3505
#            1       0.68      0.68      0.68      2065
#
#     accuracy                           0.76      5570
#    macro avg       0.74      0.75      0.74      5570
# weighted avg       0.76      0.76      0.76      5570

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_validate, KFold

# %%
def tuning_lgm():
    def objective(trial):
        params = {
            'boosting_type':'gbdt',
            'n_estimators': trial.suggest_int('n_estimators', 1, 130),
            'objective': 'binary',
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 1), 
            'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
            'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
            'num_leaves': trial.suggest_int('num_leaves', 2, 256),
            'colsample_bytree': trial.suggest_loguniform('colsample_bytree', .5, 1.),
            'subsample': trial.suggest_loguniform('subsample', .5, 1.),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
            "device":"gpu",
            "verbose":-1,
            }
        lgm = LGBMClassifier(**params,random_state=42)
        kf = KFold(n_splits=3,shuffle=True,random_state=42)
        score = cross_validate(lgm,X=X_train,y=y_train,scoring="neg_log_loss", cv=kf)
        return -1.*np.mean(score["test_score"])
    return objective

func2 = tuning_lgm()

study_lgm = optuna.create_study(direction='minimize', study_name="LGBMClassifier")
study_lgm.optimize(func2, n_trials=5)
print(study_lgm.best_params)
# Out:
# [I 2022-05-08 21:01:20,692] A new study created in memory with name: LGBMClassifier
# [I 2022-05-08 21:01:23,696] Trial 0 finished with value: 0.5224014934809751 and parameters: {'n_estimators': 30, 'learning_rate': 0.9300886110252161, 'reg_alpha': 5.751897140883505e-06, 'reg_lambda': 0.00078033122978694, 'num_leaves': 51, 'colsample_bytree': 0.7632641115161988, 'subsample': 0.6358255870644263, 'min_child_samples': 76}. Best is trial 0 with value: 0.5224014934809751.
# [I 2022-05-08 21:01:27,797] Trial 1 finished with value: 0.5650753676881862 and parameters: {'n_estimators': 71, 'learning_rate': 0.9524479399104578, 'reg_alpha': 0.013981072036977803, 'reg_lambda': 1.5945040487850798e-05, 'num_leaves': 37, 'colsample_bytree': 0.5830280307031291, 'subsample': 0.8059529916172158, 'min_child_samples': 64}. Best is trial 0 with value: 0.5224014934809751.
# ...

# %%
lgbm_model = LGBMClassifier(**study_lgm.best_params)
lgbm_eval = ModelMetrics(lgbm_model, 'classification', X_train, y_train, X_test, y_test)
lgbm_eval.model_performance()
# Out:
# Cross validation mean score is 0.2226966044585265
# Log Loss for test set is 0.4421
# Confusion matrix for test set
# [[2836  669]
#  [ 570 1495]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      3505
#            1       0.69      0.72      0.71      2065
#
#     accuracy                           0.78      5570
#    macro avg       0.76      0.77      0.76      5570
# weighted avg       0.78      0.78      0.78      5570
